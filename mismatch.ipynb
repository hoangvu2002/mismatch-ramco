# %%
import pandas as pd
from datetime import datetime

# Hiển thị đủ số dòng và số cột mong muốn
pd.set_option("display.max_rows", 100)   # tối đa số dòng hiển thị
pd.set_option("display.max_columns", None)  # hiện tất cả các cột
pd.set_option("display.width", None)   # không giới hạn độ rộng

# %%
# Đường dẫn đầy đủ tới file Excel
excel_path = r"C:\Users\huuchinh.nguyen\Concentrix Corporation\WFM-Expedia-HCM - Branding files\Attendance\Expedia - ATD Report - 2025.10.xlsx"

# Đọc sheet Roster_Rawdata
df_roster = pd.read_excel(excel_path, sheet_name="Roster_Rawdata")

# Kiểm tra kích thước và xem trước dữ liệu
print("Kích thước sheet Roster_Rawdata:", df_roster.shape)
df_roster.head()
# Out:
# Kích thước sheet Roster_Rawdata: (155, 34)
#          -        -.1                              -.2                -.3  \
# 0      IEX     Emp ID                            Email         Agent Name
# 1  3085257  103082161      thikimchi.le@concentrix.com     LE THI KIM CHI
# 2  3090069  103116487   thanhhao.nguyen@concentrix.com   NGUYEN THANH HAO
# 3  3087504  103101215  hongphuc.nguyen3@concentrix.com   NGUYEN HONG PHUC
# 4  3088783  103105143  thiminhthu.pham1@concentrix.com  PHAM THI MINH THU
#
#     -.4 2025-09-29 00:00:00 2025-09-30 00:00:00 2025-10-01 00:00:00  \
# 0  Wave           9/29/2025           9/30/2025           10/1/2025
# 1    17           2100-0600           2100-0600                 OFF
# 2    24           1300-2200           1300-2200                 OFF
# 3    20           1300-2200           1300-2200           1300-2200
# 4    20           1300-2200           1300-2200           1300-2200
#
#   2025-10-02 00:00:00 2025-10-03 00:00:00 2025-10-04 00:00:00  \
# 0           10/2/2025           10/3/2025           10/4/2025
# 1                 OFF           2000-0500           2100-0600
# 2                 OFF           1300-2200           1300-2200
# 3                 OFF                 OFF           1300-2200
# 4                 OFF                 OFF           1300-2200
#
#   2025-10-05 00:00:00 2025-10-06 00:00:00 2025-10-07 00:00:00  \
# 0           10/5/2025           10/6/2025           10/7/2025
# 1           2100-0600           2100-0600           2100-0600
# 2           1300-2200           2100-0600           2100-0600
# 3           1300-2200                 OFF      2100-0600-SHAL
# 4           1300-2200                 OFF           0500-1400
#
#   2025-10-08 00:00:00 2025-10-09 00:00:00 2025-10-10 00:00:00  \
# 0           10/8/2025           10/9/2025          10/10/2025
# 1                 OFF                 OFF           2100-0600
# 2           2100-0600           2100-0600                 OFF
# 3      2100-0600-SHAL                  AL           2100-0600
# 4           0500-1400           0500-1400                 OFF
#
#   2025-10-11 00:00:00 2025-10-12 00:00:00 2025-10-13 00:00:00  \
# 0          10/11/2025          10/12/2025          10/13/2025
# 1           2100-0600           2100-0600           2100-0600
# 2                 OFF           2100-0600           2100-0600
# 3           2100-0600                 OFF                 OFF
# 4           0500-1400           0500-1400                 OFF
#
#   2025-10-14 00:00:00 2025-10-15 00:00:00 2025-10-16 00:00:00  \
# 0          10/14/2025          10/15/2025          10/16/2025
# 1           2100-0600                 OFF                 OFF
# 2           2100-0600                  CO                  AL
# 3           2100-0600                  SL      2100-0600-SHAL
# 4           0600-1500           0500-1400           0500-1400
#
#   2025-10-17 00:00:00 2025-10-18 00:00:00 2025-10-19 00:00:00  \
# 0          10/17/2025          10/18/2025          10/19/2025
# 1           2100-0600           2100-0600           2100-0600
# 2                 OFF                 OFF           2100-0600
# 3      2100-0600-SHAL      2100-0600-SHAL                 OFF
# 4           0600-1500           0500-1400                 OFF
#
#   2025-10-20 00:00:00 2025-10-21 00:00:00 2025-10-22 00:00:00  \
# 0          10/20/2025          10/21/2025          10/22/2025
# 1           2100-0600           2100-0600                 OFF
# 2           2000-0500           2000-0500           2000-0500
# 3                 OFF      2100-0600-SHAL      2100-0600-SHAL
# 4           0500-1400           0500-1400           0500-1400
#
#   2025-10-23 00:00:00 2025-10-24 00:00:00 2025-10-25 00:00:00  \
# 0          10/23/2025          10/24/2025          10/25/2025
# 1                 OFF           2100-0600           2100-0600
# 2           2000-0500                 OFF                 OFF
# 3      2100-0600-SHAL      2100-0600-SHAL      2100-0600-SHAL
# 4           0500-1400           0500-1400                 OFF
#
#   2025-10-26 00:00:00  2025-10-27 00:00:00
# 0          10/26/2025                  NaN
# 1           2100-0600                  NaN
# 2           2000-0500                  NaN
# 3                 OFF                  NaN
# 4                 OFF                  NaN

# %%
# Loại bỏ hàng hiện đang dùng làm tên cột và đưa hàng đầu tiên của dữ liệu lên làm header mới

# Đặt hàng đầu tiên (hiện tại là dòng dữ liệu) làm tên cột mới
df_roster.columns = df_roster.iloc[0]

# Xóa hàng đầu tiên (vì đã dùng làm header)
df_roster = df_roster[1:].reset_index(drop=True)

print("Sau khi chỉnh lại header:")
print(df_roster.columns.tolist())
df_roster.head()
# Out:
# Sau khi chỉnh lại header:
# ['IEX', 'Emp ID', 'Email', 'Agent Name', 'Wave', '9/29/2025', '9/30/2025', '10/1/2025', '10/2/2025', '10/3/2025', '10/4/2025', '10/5/2025', '10/6/2025', '10/7/2025', '10/8/2025', '10/9/2025', '10/10/2025', '10/11/2025', '10/12/2025', '10/13/2025', '10/14/2025', '10/15/2025', '10/16/2025', '10/17/2025', '10/18/2025', '10/19/2025', '10/20/2025', '10/21/2025', '10/22/2025', '10/23/2025', '10/24/2025', '10/25/2025', '10/26/2025', nan]
# 0      IEX     Emp ID                             Email          Agent Name  \
# 0  3085257  103082161       thikimchi.le@concentrix.com      LE THI KIM CHI
# 1  3090069  103116487    thanhhao.nguyen@concentrix.com    NGUYEN THANH HAO
# 2  3087504  103101215   hongphuc.nguyen3@concentrix.com    NGUYEN HONG PHUC
# 3  3088783  103105143   thiminhthu.pham1@concentrix.com   PHAM THI MINH THU
# 4  3008097  102843519  songnguyen.nguyen@concentrix.com  NGUYEN SONG NGUYEN
#
# 0 Wave  9/29/2025  9/30/2025  10/1/2025 10/2/2025  10/3/2025  10/4/2025  \
# 0   17  2100-0600  2100-0600        OFF       OFF  2000-0500  2100-0600
# 1   24  1300-2200  1300-2200        OFF       OFF  1300-2200  1300-2200
# 2   20  1300-2200  1300-2200  1300-2200       OFF        OFF  1300-2200
# 3   20  1300-2200  1300-2200  1300-2200       OFF        OFF  1300-2200
# 4   26  2000-0500         AL        OFF       OFF  2000-0500  2000-0500
#
# 0  10/5/2025  10/6/2025       10/7/2025       10/8/2025  10/9/2025 10/10/2025  \
# 0  2100-0600  2100-0600       2100-0600             OFF        OFF  2100-0600
# 1  1300-2200  2100-0600       2100-0600       2100-0600  2100-0600        OFF
# 2  1300-2200        OFF  2100-0600-SHAL  2100-0600-SHAL         AL  2100-0600
# 3  1300-2200        OFF       0500-1400       0500-1400  0500-1400        OFF
# 4  2000-0500        OFF       0600-1500       0600-1500  0600-1500  0600-1500
#
# 0 10/11/2025 10/12/2025 10/13/2025 10/14/2025 10/15/2025      10/16/2025  \
# 0  2100-0600  2100-0600  2100-0600  2100-0600        OFF             OFF
# 1        OFF  2100-0600  2100-0600  2100-0600         CO              AL
# 2  2100-0600        OFF        OFF  2100-0600         SL  2100-0600-SHAL
# 3  0500-1400  0500-1400        OFF  0600-1500  0500-1400       0500-1400
# 4  0600-1500        OFF        OFF  1300-2200  1300-2200       1300-2200
#
# 0      10/17/2025      10/18/2025 10/19/2025 10/20/2025      10/21/2025  \
# 0       2100-0600       2100-0600  2100-0600  2100-0600       2100-0600
# 1             OFF             OFF  2100-0600  2000-0500       2000-0500
# 2  2100-0600-SHAL  2100-0600-SHAL        OFF        OFF  2100-0600-SHAL
# 3       0600-1500       0500-1400        OFF  0500-1400       0500-1400
# 4       1300-2200       1300-2200        OFF        OFF       1300-2200
#
# 0      10/22/2025      10/23/2025      10/24/2025      10/25/2025 10/26/2025  \
# 0             OFF             OFF       2100-0600       2100-0600  2100-0600
# 1       2000-0500       2000-0500             OFF             OFF  2000-0500
# 2  2100-0600-SHAL  2100-0600-SHAL  2100-0600-SHAL  2100-0600-SHAL        OFF
# 3       0500-1400       0500-1400       0500-1400             OFF        OFF
# 4       1300-2200       1300-2200              AL              AL        OFF
#
# 0  NaN
# 0  NaN
# 1  NaN
# 2  NaN
# 3  NaN
# 4  NaN

# %%
# Đọc sheet ATD_Final
atd_final_df = pd.read_excel(excel_path, sheet_name="ATD_Final")

# Đảm bảo cột Date trong atd_final_df có định dạng tháng/ngày/năm
atd_final_df['Date'] = pd.to_datetime(atd_final_df['Date'], errors='coerce').dt.strftime('%#m/%#d/%Y')


# Kiểm tra vài dòng đầu
atd_final_df.head()
# Out:
#    Year   Month    Site Date Start Week  Day       Date   OracleID   IEX ID  \
# 0  2025  Oct-25  ONEHUB      2025-09-29  Wed  10/1/2025  102458550  3083115
# 1  2025  Oct-25  ONEHUB      2025-09-29  Wed  10/1/2025  103082161  3085257
# 2  2025  Oct-25  ONEHUB      2025-09-29  Thu  10/2/2025  103082161  3085257
# 3  2025  Oct-25  ONEHUB      2025-09-29  Wed  10/1/2025  102478278  3084782
# 4  2025  Oct-25  ONEHUB      2025-09-29  Wed  10/1/2025  102821757  3004041
#
#      Employee Name  Alias      LOB      TL ID      Supervisor Name  \
# 0  TRAN THI THU HA  Nancy  Lodging  102211179           To Anh Duy
# 1   LE THI KIM CHI  Sarah  Lodging  102456914  Nguyen Dinh Nhu Hao
# 2   LE THI KIM CHI  Sarah  Lodging  102456914  Nguyen Dinh Nhu Hao
# 3    VO THANH TIEN   Auty  Lodging  102371964       Tran Thao Uyen
# 4   THAI HOANG PHU   Nine  Lodging  102456914  Nguyen Dinh Nhu Hao
#
#   Manager/OM Name                       Email Id Wave LWD/Movement  \
# 0    Patar Kirpan  thithuha.tran1@concentrix.com    4          NaT
# 1    Patar Kirpan    thikimchi.le@concentrix.com   17          NaT
# 2    Patar Kirpan    thikimchi.le@concentrix.com   17          NaT
# 3    Patar Kirpan    thanhtien.vo@concentrix.com    5          NaT
# 4    Patar Kirpan   hoangphu.thai@concentrix.com    9          NaT
#
#             Detail Status LOB_2 LOB_3 Active Original.Shift RTA.Start_Shift  \
# 0      Lodging Production     0     0    Yes            OFF             NaN
# 1  Non Lodging Production     0     0    Yes            OFF             NaN
# 2  Non Lodging Production     0     0    Yes            OFF             NaN
# 3  Non Lodging Production     0     0    Yes            OFF             NaN
# 4  Non Lodging Production     0     0    Yes            OFF             NaN
#
#   RTA.End_Shift  Night_Shift Shift Tracking  Roster Presented  \
# 0           NaN            0            Off               0.0
# 1           NaN            0            Off               0.0
# 2           NaN            0            Off               0.0
# 3           NaN            0            Off               0.0
# 4           NaN            0            Off               0.0
#
#    Roster Scheduled  Target Start Time End Time  Duration  HC Actual  \
# 0               0.0     0.0        NaT      NaT       0.0        0.0
# 1               0.0     0.0        NaT      NaT       0.0        0.0
# 2               0.0     0.0        NaT      NaT       0.0        0.0
# 3               0.0     0.0        NaT      NaT       0.0        0.0
# 4               0.0     0.0        NaT      NaT       0.0        0.0
#
#   Time_Late Time_Leave  Lateness  Open Time   OT  NCNS  SUM Productive  \
# 0       NaN        NaN       NaN        0.0  0.0   0.0             0.0
# 1       NaN        NaN       NaN        0.0  0.0   0.0             0.0
# 2       NaN        NaN       NaN        0.0  0.0   0.0             0.0
# 3       NaN        NaN       NaN        0.0  0.0   0.0             0.0
# 4       NaN        NaN       NaN        0.0  0.0   0.0             0.0
#
#    OT Ramco NSA Group  OT Group NM Group Ramco Marked  HC Schedule  \
# 0       0.0       NaN       NaN      NaN           WO            0
# 1       0.0       NaN       NaN      NaN           WO            0
# 2       0.0       NaN       NaN      NaN           WO            0
# 3       0.0       NaN       NaN      NaN           WO            0
# 4       0.0       NaN       NaN      NaN           WO            0
#
#   Leave.Shift Leave.Leave_Datetime_Start_Shift Leave.Leave_Datetime_End_Shift  \
# 0         NaN                              NaT                            NaT
# 1         NaN                              NaT                            NaT
# 2         NaN                              NaT                            NaT
# 3         NaN                              NaT                            NaT
# 4         NaN                              NaT                            NaT
#
#   Leave Reason Leave.Remark Remark Datetime_Start_Shift Datetime_End_Shift  \
# 0   NaN    NaN          NaN    NaN                  NaT                NaT
# 1   NaN    NaN          NaN    NaN                  NaT                NaT
# 2   NaN    NaN          NaN    NaN                  NaT                NaT
# 3   NaN    NaN          NaN    NaN                  NaT                NaT
# 4   NaN    NaN          NaN    NaN                  NaT                NaT
#
#   Shift Attendance  Present  Planned  Unplanned  In Office  Re_Check  \
# 0   OFF         WO      0.0      0.0        0.0        NaN      True
# 1   OFF         WO      0.0      0.0        0.0        NaN      True
# 2   OFF         WO      0.0      0.0        0.0        NaN      True
# 3   OFF         WO      0.0      0.0        0.0        NaN      True
# 4   OFF         WO      0.0      0.0        0.0        NaN      True
#
#    Ramco_ReCheck  Productive  Final_HC_Actual  HC_Schedule_Sum  Volume  \
# 0           True         0.0              0.0               85     NaN
# 1           True         0.0              0.0               85     NaN
# 2           True         0.0              0.0               80     NaN
# 3           True         0.0              0.0               85     NaN
# 4           True         0.0              0.0               85     NaN
#
#    Re-Direct  Exceed Chat
# 0        NaN          NaN
# 1        NaN          NaN
# 2        NaN          NaN
# 3        NaN          NaN
# 4        NaN          NaN

# %%
# Tính cột Actual Attendance
def compute_actual_attendance(row):
    schedule = str(row['Shift']).strip().upper()
    
    # Các trạng thái không tính attendance
    invalid_status = {"TERMINATION", "OFF CHAT", "", "0", "REMOVED"}
    if schedule in invalid_status:
        return ""
    
    # Trường hợp Mentor
    if schedule == "MENTOR":
        return "PR"
    
    # Các trường hợp còn lại giữ nguyên attendance gốc
    return row['Attendance']

atd_final_df['Actual Attendance'] = atd_final_df.apply(compute_actual_attendance, axis=1)

# Kiểm tra kết quả
atd_final_df.head()
# Out:
#    Year   Month    Site Date Start Week  Day       Date   OracleID   IEX ID  \
# 0  2025  Oct-25  ONEHUB      2025-09-29  Wed  10/1/2025  102458550  3083115
# 1  2025  Oct-25  ONEHUB      2025-09-29  Wed  10/1/2025  103082161  3085257
# 2  2025  Oct-25  ONEHUB      2025-09-29  Thu  10/2/2025  103082161  3085257
# 3  2025  Oct-25  ONEHUB      2025-09-29  Wed  10/1/2025  102478278  3084782
# 4  2025  Oct-25  ONEHUB      2025-09-29  Wed  10/1/2025  102821757  3004041
#
#      Employee Name  Alias      LOB      TL ID      Supervisor Name  \
# 0  TRAN THI THU HA  Nancy  Lodging  102211179           To Anh Duy
# 1   LE THI KIM CHI  Sarah  Lodging  102456914  Nguyen Dinh Nhu Hao
# 2   LE THI KIM CHI  Sarah  Lodging  102456914  Nguyen Dinh Nhu Hao
# 3    VO THANH TIEN   Auty  Lodging  102371964       Tran Thao Uyen
# 4   THAI HOANG PHU   Nine  Lodging  102456914  Nguyen Dinh Nhu Hao
#
#   Manager/OM Name                       Email Id Wave LWD/Movement  \
# 0    Patar Kirpan  thithuha.tran1@concentrix.com    4          NaT
# 1    Patar Kirpan    thikimchi.le@concentrix.com   17          NaT
# 2    Patar Kirpan    thikimchi.le@concentrix.com   17          NaT
# 3    Patar Kirpan    thanhtien.vo@concentrix.com    5          NaT
# 4    Patar Kirpan   hoangphu.thai@concentrix.com    9          NaT
#
#             Detail Status LOB_2 LOB_3 Active Original.Shift RTA.Start_Shift  \
# 0      Lodging Production     0     0    Yes            OFF             NaN
# 1  Non Lodging Production     0     0    Yes            OFF             NaN
# 2  Non Lodging Production     0     0    Yes            OFF             NaN
# 3  Non Lodging Production     0     0    Yes            OFF             NaN
# 4  Non Lodging Production     0     0    Yes            OFF             NaN
#
#   RTA.End_Shift  Night_Shift Shift Tracking  Roster Presented  \
# 0           NaN            0            Off               0.0
# 1           NaN            0            Off               0.0
# 2           NaN            0            Off               0.0
# 3           NaN            0            Off               0.0
# 4           NaN            0            Off               0.0
#
#    Roster Scheduled  Target Start Time End Time  Duration  HC Actual  \
# 0               0.0     0.0        NaT      NaT       0.0        0.0
# 1               0.0     0.0        NaT      NaT       0.0        0.0
# 2               0.0     0.0        NaT      NaT       0.0        0.0
# 3               0.0     0.0        NaT      NaT       0.0        0.0
# 4               0.0     0.0        NaT      NaT       0.0        0.0
#
#   Time_Late Time_Leave  Lateness  Open Time   OT  NCNS  SUM Productive  \
# 0       NaN        NaN       NaN        0.0  0.0   0.0             0.0
# 1       NaN        NaN       NaN        0.0  0.0   0.0             0.0
# 2       NaN        NaN       NaN        0.0  0.0   0.0             0.0
# 3       NaN        NaN       NaN        0.0  0.0   0.0             0.0
# 4       NaN        NaN       NaN        0.0  0.0   0.0             0.0
#
#    OT Ramco NSA Group  OT Group NM Group Ramco Marked  HC Schedule  \
# 0       0.0       NaN       NaN      NaN           WO            0
# 1       0.0       NaN       NaN      NaN           WO            0
# 2       0.0       NaN       NaN      NaN           WO            0
# 3       0.0       NaN       NaN      NaN           WO            0
# 4       0.0       NaN       NaN      NaN           WO            0
#
#   Leave.Shift Leave.Leave_Datetime_Start_Shift Leave.Leave_Datetime_End_Shift  \
# 0         NaN                              NaT                            NaT
# 1         NaN                              NaT                            NaT
# 2         NaN                              NaT                            NaT
# 3         NaN                              NaT                            NaT
# 4         NaN                              NaT                            NaT
#
#   Leave Reason Leave.Remark Remark Datetime_Start_Shift Datetime_End_Shift  \
# 0   NaN    NaN          NaN    NaN                  NaT                NaT
# 1   NaN    NaN          NaN    NaN                  NaT                NaT
# 2   NaN    NaN          NaN    NaN                  NaT                NaT
# 3   NaN    NaN          NaN    NaN                  NaT                NaT
# 4   NaN    NaN          NaN    NaN                  NaT                NaT
#
#   Shift Attendance  Present  Planned  Unplanned  In Office  Re_Check  \
# 0   OFF         WO      0.0      0.0        0.0        NaN      True
# 1   OFF         WO      0.0      0.0        0.0        NaN      True
# 2   OFF         WO      0.0      0.0        0.0        NaN      True
# 3   OFF         WO      0.0      0.0        0.0        NaN      True
# 4   OFF         WO      0.0      0.0        0.0        NaN      True
#
#    Ramco_ReCheck  Productive  Final_HC_Actual  HC_Schedule_Sum  Volume  \
# 0           True         0.0              0.0               85     NaN
# 1           True         0.0              0.0               85     NaN
# 2           True         0.0              0.0               80     NaN
# 3           True         0.0              0.0               85     NaN
# 4           True         0.0              0.0               85     NaN
#
#    Re-Direct  Exceed Chat Actual Attendance
# 0        NaN          NaN                WO
# 1        NaN          NaN                WO
# 2        NaN          NaN                WO
# 3        NaN          NaN                WO
# 4        NaN          NaN                WO

# %%
# Đọc 3 file CSV
ramco_df = pd.read_csv("ramco_processed_oct_2025.csv")
active_df = pd.read_csv("Active.csv")
inactive_df = pd.read_csv("Inactive.csv")

# Hiển thị vài dòng đầu tiên của mỗi file
#ramco_df.head()
#active_df.head()
inactive_df.head()
# Out:
#    Site Queue Group CSG Joining Data Location  People ID  IEX ID   OracleID  \
# 0  QTSC           -                -  Vietnam        NaN     NaN  102356310
# 1  QTSC           -                -  Vietnam        NaN     NaN  102369332
# 2  QTSC           -                -  Vietnam        NaN     NaN  102361154
# 3  QTSC           -                -  Vietnam        NaN     NaN  102370708
# 4     -           -                -  Vietnam        NaN     NaN  102464530
#
#            Employee Name Alias  Gender  Contract Start Date  \
# 0         LE THANH PHONG   NaN    Male  2023-10-25 00:00:00
# 1         LE BAO NGOC AN   NaN  Female  2023-11-15 00:00:00
# 2       HUYNH QUANG TIEN   NaN    Male  2023-11-02 00:00:00
# 3  TRAN NGOC KHANH DUYEN   NaN  Female  2023-11-20 00:00:00
# 4          PHAM MINH THU   NaN  Female                    -
#
#      Contract End Date                     Designation     Grade      LOB  \
# 0  2024-10-24 00:00:00  Supervisor, Training & Quality  Grade 9A  Support
# 1  2024-11-14 00:00:00  Supervisor, Training & Quality  Grade 9A  Support
# 2  2024-11-01 00:00:00         Team Leader, Operations  Grade 9A  Support
# 3  2024-01-18 00:00:00     Advisor I, Customer Service  Grade 12  Lodging
# 4                    -     Advisor I, Customer Service  Grade 12        -
#
#           Role Multiple Chat Effective Date Primary role Secondary role  \
# 0          NaN                          NaN            -              -
# 1          NaN                          NaN            -              -
# 2          NaN                          NaN            -              -
# 3  Single_Chat                          NaN         Chat              -
# 4          NaN                          NaN            -              -
#
#        TL ID Supervisor Name                    Supervisor Email  \
# 0  102321297   JoRoy Alcazar  jonathanroy.alcazar@concentrix.com
# 1  102321297   JoRoy Alcazar  jonathanroy.alcazar@concentrix.com
# 2  102240407     Han My Linh           mylinh.han@concentrix.com
# 3  102264985  Tran Viet Hung        viethung.tran@concentrix.com
# 4          -               -                                   -
#
#                Manager Name                            Email Id    Wave  \
# 0            Gaurav Thakkar    lethanhphong.tran@concentrix.com  APAC 3
# 1            Gaurav Thakkar         baongocan.le@concentrix.com  APAC 3
# 2          Rojo Sir William      quangtien.huynh@concentrix.com  APAC 3
# 3  Pradeep Kumar Bahadursha  ngockhanhduyen.tran@concentrix.com      1B
# 4                         -                                 NaN      3B
#
#           CCT Training Lodging - Training start date   \
# 0  2023-11-06 00:00:00            2023-11-06 00:00:00
# 1  2023-11-06 00:00:00            2023-11-06 00:00:00
# 2  2023-11-06 00:00:00            2023-11-06 00:00:00
# 3  2023-11-20 00:00:00            2023-11-20 00:00:00
# 4  2024-01-02 00:00:00            2024-01-02 00:00:00
#
#   Lodging - Training end date Lodging - Nesting Date  \
# 0         2023-12-29 00:00:00    2024-01-02 00:00:00
# 1         2023-12-29 00:00:00    2024-01-02 00:00:00
# 2         2023-12-29 00:00:00    2024-01-02 00:00:00
# 3         2023-12-15 00:00:00    2023-12-18 00:00:00
# 4         2024-01-26 00:00:00    2024-01-29 00:00:00
#
#   Lodging - Certification Date (Original)  \
# 0                     2024-01-12 00:00:00
# 1                     2024-01-12 00:00:00
# 2                     2024-01-12 00:00:00
# 3                     2023-12-29 00:00:00
# 4                     2024-02-11 00:00:00
#
#   Lodging - Certification Date (Actual) Lodging - Certification status  \
# 0                                     -                              -
# 1                                     -                              -
# 2                                     -                              -
# 3                                     -                              -
# 4                                     -                              -
#
#   Non-Lodging - Training start date  Non-Lodging - Training end date  \
# 0                                  -                               -
# 1                                  -                               -
# 2                                  -                               -
# 3                                  -                               -
# 4                                  -                               -
#
#   Non-Lodging - Nesting Date Non-Lodging - Certification Date  \
# 0                          -                                -
# 1                          -                                -
# 2                          -                                -
# 3                          -                                -
# 4                          -                                -
#
#   Non-Lodging - Certification Date (Actual)  \
# 0                                       NaN
# 1                                       NaN
# 2                                       NaN
# 3                                       NaN
# 4                                       NaN
#
#   Non-Lodging - Certification status Production Date AON Tenure  \
# 0                                  -               -   -      -
# 1                                  -               -   -      -
# 2                                  -               -   -      -
# 3                                  -               -   -      -
# 4                                  -               -   -      -
#
#   Current Queue Production Date Current Queue Production Duration  \
# 0                             -                                 -
# 1                             -                                 -
# 2                             -                                 -
# 3                             -                                 -
# 4                             -                                 -
#
#   Current Queue Tenure Nationality      MSA Current Console Queue  \
# 0                    -  Vietnamese  Expedia                     -
# 1                    -  Vietnamese  Expedia                     -
# 2                    -  Vietnamese  Expedia                     -
# 3                    -  Vietnamese  Expedia    Chat_OD_EN_Lodging
# 4                    -  Vietnamese  Expedia                     -
#
#           LWD/Movement Attrition Type  \
# 0  2023-11-10 00:00:00      Voluntary
# 1  2023-11-21 00:00:00      Voluntary
# 2  2023-11-26 00:00:00    Involuntary
# 3  2023-12-01 00:00:00    Involuntary
# 4  2024-01-02 00:00:00            NaN
#
#                                 Reason for Attrition   Month  \
# 0          Terminate Employee > Voluntary > Personal  Nov'23
# 1          Terminate Employee > Voluntary > Personal  Nov'23
# 2  Terminate Employee > Involuntary > Failed to M...  Nov'23
# 3  Terminate Employee > Involuntary > Attendance ...  Dec'23
# 4                                                DNS  Jan'24
#
#            Week Ending     Termination Date      Duration  \
# 0  2023-11-12 00:00:00  2023-11-10 00:00:00   In Training
# 1  2023-11-26 00:00:00  2023-11-21 00:00:00   In Training
# 2  2023-11-26 00:00:00  2023-11-26 00:00:00   In Training
# 3  2023-12-03 00:00:00  2023-12-01 00:00:00   In Training
# 4  2024-01-07 00:00:00                    -  CCT Training
#
#                     WS                 Note Okta Deletion  \
# 0  2023-11-06 00:00:00                  NaN             Y
# 1  2023-11-20 00:00:00                  NaN             Y
# 2  2023-11-20 00:00:00                  NaN             Y
# 3  2023-11-27 00:00:00                  NaN             Y
# 4                       Dropped in Training             Y
#
#   Check if still stay in Active sheet
# 0                                  No
# 1                                  No
# 2                                  No
# 3                                  No
# 4                                  No

# %%
# Merge với active_df trước
active_merge = atd_final_df[['OracleID', 'Date', 'Employee Name', 'Actual Attendance']].merge(
    active_df[['OracleID', 'LOB', 'Supervisor Name', 'Manager/OM Name']],
    on='OracleID',
    how='left'
)

# Merge với inactive_df (và đổi tên cột Manager Name)
inactive_merge = atd_final_df[['OracleID', 'Date', 'Employee Name', 'Actual Attendance']].merge(
    inactive_df[['OracleID', 'LOB', 'Supervisor Name', 'Manager Name']].rename(
        columns={'Manager Name': 'Manager/OM Name'}
    ),
    on='OracleID',
    how='left'
)

# Dùng combine_first để lấy giá trị từ inactive nếu active bị thiếu
report_base_df = active_merge.combine_first(inactive_merge)

# Hiển thị kết quả mẫu
report_base_df.head()
# Out:
#     OracleID       Date    Employee Name Actual Attendance      LOB  \
# 0  102458550  10/1/2025  TRAN THI THU HA                WO  Lodging
# 1  103082161  10/1/2025   LE THI KIM CHI                WO  Lodging
# 2  103082161  10/2/2025   LE THI KIM CHI                WO  Lodging
# 3  102478278  10/1/2025    VO THANH TIEN                WO  Lodging
# 4  102821757  10/1/2025   THAI HOANG PHU                WO  Lodging
#
#        Supervisor Name Manager/OM Name
# 0           To Anh Duy    Patar Kirpan
# 1  Nguyen Dinh Nhu Hao    Patar Kirpan
# 2  Nguyen Dinh Nhu Hao    Patar Kirpan
# 3       Tran Thao Uyen    Patar Kirpan
# 4  Nguyen Dinh Nhu Hao    Patar Kirpan

# %%
# Unpivot (melt) các cột ngày trong ramco_df
# Giả sử các cột không phải ngày là các cột định danh (ID, Name, v.v.)

id_vars = ['Oracle_ID', 'Employee Name']  # thay đổi nếu bạn có thêm các cột định danh khác
value_vars = [col for col in ramco_df.columns if col not in id_vars]

ramco_unpivot_df = ramco_df.melt(
    id_vars=id_vars,
    value_vars=value_vars,
    var_name='Date',
    value_name='Ramco Attendance'
)

# Chuẩn hóa lại cột Date nếu cần (nếu cột đang là dạng chuỗi YYYY-MM-DD)
ramco_unpivot_df['Date'] = pd.to_datetime(ramco_unpivot_df['Date'], errors='coerce').dt.strftime('%#m/%#d/%Y')

# Xem vài dòng đầu
ramco_unpivot_df
# Out:
#         Oracle_ID               Employee Name        Date Ramco Attendance
# 0            2212                Nadia  Durri   10/1/2025               NM
# 1            2892                 Matt  Bagby   10/1/2025               NM
# 2           10067                   Kenny  Ng   10/1/2025               NM
# 3           10658        Jayavelu  Maripillai   10/1/2025               NM
# 4           14211                  Pammy  Leo   10/1/2025               NM
# ...           ...                         ...         ...              ...
# 662837     884365              NORLEZA  SEMAN  10/31/2025               NM
# 662838     885486  PAVITHIRAN  SHUNMUGANATHAN  10/31/2025               NM
# 662839     886398    NESSIE DAWN OBSID  TANZO  10/31/2025               NM
# 662840     887374              REVATHI  MOGAN  10/31/2025               NM
# 662841     892259              SANDEEP  KUMAR  10/31/2025               NM
#
# [662842 rows x 4 columns]

# %%
# Đảm bảo tên cột khớp trước khi merge
ramco_unpivot_df = ramco_unpivot_df.rename(columns={'Oracle_ID': 'OracleID'})

# Gộp dữ liệu từ ramco_unpivot_df vào report_base_df theo OracleID + Date
report_base_df = report_base_df.merge(
    ramco_unpivot_df[['OracleID', 'Date', 'Ramco Attendance']],
    on=['OracleID', 'Date'],
    how='left'
)

# Kiểm tra kết quả sau khi thêm cột Ramco Attendance
report_base_df
# Out:
#        OracleID        Date       Employee Name Actual Attendance      LOB  \
# 0     102458550   10/1/2025     TRAN THI THU HA                WO  Lodging
# 1     103082161   10/1/2025      LE THI KIM CHI                WO  Lodging
# 2     103082161   10/2/2025      LE THI KIM CHI                WO  Lodging
# 3     102478278   10/1/2025       VO THANH TIEN                WO  Lodging
# 4     102821757   10/1/2025      THAI HOANG PHU                WO  Lodging
# ...         ...         ...                 ...               ...      ...
# 3549  102871040  10/14/2025  TRAN PHAM MINH THU               HAL  Lodging
# 3550  103283831  10/18/2025      TRAN TUAN KHOI               HAL  Lodging
# 3551  103109357  10/18/2025       VUU TIEN NHAN               HAL  Lodging
# 3552  103085298  10/18/2025          DOAN AN NY               HAL  Lodging
# 3553  102864715  10/22/2025    NGO VAN MINH DUY               HAL  Lodging
#
#               Supervisor Name Manager/OM Name Ramco Attendance
# 0                  To Anh Duy    Patar Kirpan               WO
# 1         Nguyen Dinh Nhu Hao    Patar Kirpan               WO
# 2         Nguyen Dinh Nhu Hao    Patar Kirpan               WO
# 3              Tran Thao Uyen    Patar Kirpan               WO
# 4         Nguyen Dinh Nhu Hao    Patar Kirpan               WO
# ...                       ...             ...              ...
# 3549                      Ann    Patar Kirpan              HAL
# 3550  Truong Thien Thanh Toan    Patar Kirpan              HAL
# 3551               To Anh Duy    Patar Kirpan              HAL
# 3552               To Anh Duy    Patar Kirpan              HAL
# 3553              Mia Minh Lê    Patar Kirpan               PR
#
# [3554 rows x 8 columns]

# %%
# Đặt khoảng ngày cần hiển thị
start_date = "10/1/2025"
end_date = "10/15/2025"

# Chuyển cột Date về dạng datetime để lọc
report_base_df['Date_dt'] = pd.to_datetime(report_base_df['Date'], errors='coerce')
start_dt = pd.to_datetime(start_date)
end_dt = pd.to_datetime(end_date)

# Lọc dữ liệu theo khoảng ngày mong muốn
filtered_report_df = report_base_df[
    (report_base_df['Date_dt'] >= start_dt) & (report_base_df['Date_dt'] <= end_dt)
]

#Những agent đã bị ter sẽ bị hiện giá trị LOB, Supervisor Name là NaN, vì thế cần map những dòng mà có LOB, hoặc Supervisor Name là NaN thì
#sẽ map nó với bảng inactive

# Hiển thị kết quả
filtered_report_df
# Out:
#        OracleID        Date         Employee Name Actual Attendance      LOB  \
# 0     102458550   10/1/2025       TRAN THI THU HA                WO  Lodging
# 1     103082161   10/1/2025        LE THI KIM CHI                WO  Lodging
# 2     103082161   10/2/2025        LE THI KIM CHI                WO  Lodging
# 3     102478278   10/1/2025         VO THANH TIEN                WO  Lodging
# 4     102821757   10/1/2025        THAI HOANG PHU                WO  Lodging
# ...         ...         ...                   ...               ...      ...
# 3545  103109090   10/8/2025        VI LE HOAI ANH               HAL  Lodging
# 3546  102477510  10/11/2025  HUYNH NGOC HUE TRANG               HAL  Lodging
# 3547  103085298  10/12/2025            DOAN AN NY               HAL  Lodging
# 3548  103109091  10/12/2025       NGUYEN NGOC SON               HAL  Lodging
# 3549  102871040  10/14/2025    TRAN PHAM MINH THU               HAL  Lodging
#
#           Supervisor Name Manager/OM Name Ramco Attendance    Date_dt
# 0              To Anh Duy    Patar Kirpan               WO 2025-10-01
# 1     Nguyen Dinh Nhu Hao    Patar Kirpan               WO 2025-10-01
# 2     Nguyen Dinh Nhu Hao    Patar Kirpan               WO 2025-10-02
# 3          Tran Thao Uyen    Patar Kirpan               WO 2025-10-01
# 4     Nguyen Dinh Nhu Hao    Patar Kirpan               WO 2025-10-01
# ...                   ...             ...              ...        ...
# 3545           To Anh Duy    Patar Kirpan              HAL 2025-10-08
# 3546          Tran Sharon    Patar Kirpan              HAL 2025-10-11
# 3547           To Anh Duy    Patar Kirpan              HAL 2025-10-12
# 3548           To Anh Duy    Patar Kirpan              HAL 2025-10-12
# 3549                  Ann    Patar Kirpan              HAL 2025-10-14
#
# [2001 rows x 9 columns]
