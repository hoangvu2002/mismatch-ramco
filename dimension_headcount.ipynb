# %%
import pandas as pd
import os

# Hiển thị đủ số dòng và số cột mong muốn
pd.set_option("display.max_rows", 100)   # tối đa số dòng hiển thị
pd.set_option("display.max_columns", None)  # hiện tất cả các cột
pd.set_option("display.width", None)   # không giới hạn độ rộng

# %%
# --- 1. Đọc dữ liệu từ file master ---
master_path = r"C:\Users\huuchinh.nguyen\Concentrix Corporation\WFM-Expedia-HCM - Branding files\Headcount\HC Master Database - 2025.xlsx"

# Đọc sheet "Active"
df = pd.read_excel(master_path, sheet_name="Active")

# --- 2. Chỉ giữ lại các cột cần thiết ---
cols_needed = ["Site", "IEX ID", "Employee Name", "LOB", "Supervisor Name", "Email Id"]
df = df[cols_needed]

# --- 3. Xuất ra file Excel mới ---
output_path = r"C:\Users\huuchinh.nguyen\Concentrix Corporation\WFM-Expedia-HCM - Branding files\Vu\unscheduled-agent\dimension-headcount.xlsx"

# Nếu file đã tồn tại thì xoá trước khi ghi lại
if os.path.exists(output_path):
    os.remove(output_path)

df.to_excel(output_path, index=False)

print("✅ File dimension-headcount.xlsx đã được tạo tại:")
print(output_path)

# Xem thử 50 dòng đầu tiên
df
# Out:
# ✅ File dimension-headcount.xlsx đã được tạo tại:
# C:\Users\huuchinh.nguyen\Concentrix Corporation\WFM-Expedia-HCM - Branding files\Vu\unscheduled-agent\dimension-headcount.xlsx
#        Site     IEX ID            Employee Name      LOB  \
# 0    ONEHUB  3085545.0               DOAN AN NY  Lodging
# 1    ONEHUB        NaN         NGUYEN HUU CHINH      WFM
# 2    ONEHUB  3020945.0  TRUONG THIEN THANH TOAN  Support
# 3    ONEHUB  3061192.0               TO ANH DUY  Support
# 4    ONEHUB        NaN              LE LAM MINH  Support
# ..      ...        ...                      ...      ...
# 130  ONEHUB  3112804.0      NGUYEN THI THU THUY  Lodging
# 131  ONEHUB  3112809.0     DUONG THI THUY DUONG  Lodging
# 132  ONEHUB  3112765.0            DANG CHAU ANH  Lodging
# 133  ONEHUB  3112783.0      NGUYEN THI KIM LIEN  Lodging
# 134  ONEHUB  3112792.0        TRAN VU HOAI LINH  Lodging
#
#              Supervisor Name                              Email Id
# 0                 To Anh Duy              anny.doan@concentrix.com
# 1                   Tran Van        huuchinh.nguyen@concentrix.com
# 2               Patar Kirpan  thienthanhtoan.truong@concentrix.com
# 3               Patar Kirpan              anhduy.to@concentrix.com
# 4                  Tran Tran             lamminh.le@concentrix.com
# ..                       ...                                   ...
# 130  Truong Thien Thanh Toan      thithuthuy.nguyen@concentrix.com
# 131  Truong Thien Thanh Toan     thithuyduong.duong@concentrix.com
# 132  Truong Thien Thanh Toan           chauanh.dang@concentrix.com
# 133  Truong Thien Thanh Toan      thikimlien.nguyen@concentrix.com
# 134  Truong Thien Thanh Toan        vuhoailinh.tran@concentrix.com
#
# [135 rows x 6 columns]
